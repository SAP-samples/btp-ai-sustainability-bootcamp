# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import cv2

# %%
import glob

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
files=glob.glob('../data/Images/NG/*')

# %%
path='../data/Images/NG/00342_NG_Image.bmp'
im=cv2.imread(path,0)
plt.imshow(im)

# %%
clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(8,8))
cl1 = clahe.apply(im)
plt.imshow(cl1)
